# %%
import arcgis as ag
from arcgis.gis import GIS

# %%
gis = GIS()
print(f"Connected to {gis.properties.portalHostname} as {gis.users.me.username}")
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ~/anaconda3/envs/csce590/lib/python3.8/site-packages/arcgis/gis/_impl/_con/_connection.py in post(self, path, params, files, **kwargs)
#    1034             elif self._create_time is None and \
# -> 1035                  self._product in ['PORTAL', "AGOL",
#    1036                                    "AGO", "ENTERPRISE"] and \
#
# ~/anaconda3/envs/csce590/lib/python3.8/site-packages/requests/sessions.py in post(self, url, data, json, **kwargs)
#     589
# --> 590         return self.request('POST', url, data=data, json=json, **kwargs)
#     591
#
# ~/anaconda3/envs/csce590/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#
# ~/anaconda3/envs/csce590/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     661         # Response manipulation hooks
# --> 662         r = dispatch_hook('response', hooks, r, **kwargs)
#     663
#
# ~/anaconda3/envs/csce590/lib/python3.8/site-packages/requests/hooks.py in dispatch_hook(key, hooks, hook_data, **kwargs)
#      30         for hook in hooks:
# ---> 31             _hook_data = hook(hook_data, **kwargs)
#      32             if _hook_data is not None:
#
# ~/anaconda3/envs/csce590/lib/python3.8/site-packages/requests_kerberos/kerberos_.py in handle_response(self, response, **kwargs)
#     380             # If we haven't tried, try getting it now
# --> 381             cbt_application_data = _get_channel_bindings_application_data(response)
#     382             if cbt_application_data:
#
# ~/anaconda3/envs/csce590/lib/python3.8/site-packages/requests_kerberos/kerberos_.py in _get_channel_bindings_application_data(response)
#     154             else:
# --> 155                 certificate_hash = _get_certificate_hash(server_certificate)
#     156                 application_data = b'tls-server-end-point:' + certificate_hash
#
# ~/anaconda3/envs/csce590/lib/python3.8/site-packages/requests_kerberos/kerberos_.py in _get_certificate_hash(certificate_der)
#      99     # https://tools.ietf.org/html/rfc5929#section-4.1
# --> 100     cert = x509.load_der_x509_certificate(certificate_der, default_backend())
#     101
#
# ~/anaconda3/envs/csce590/lib/python3.8/site-packages/cryptography/hazmat/backends/__init__.py in default_backend()
#      13     if _default_backend is None:
# ---> 14         from cryptography.hazmat.backends.openssl.backend import backend
#      15
#
# ~/anaconda3/envs/csce590/lib/python3.8/site-packages/cryptography/hazmat/backends/openssl/__init__.py in <module>
#       5
# ----> 6 from cryptography.hazmat.backends.openssl.backend import backend
#       7
#
# ~/anaconda3/envs/csce590/lib/python3.8/site-packages/cryptography/hazmat/backends/openssl/backend.py in <module>
#     112 )
# --> 113 from cryptography.hazmat.bindings.openssl import binding
#     114 from cryptography.hazmat.primitives import hashes, serialization
#
# ~/anaconda3/envs/csce590/lib/python3.8/site-packages/cryptography/hazmat/bindings/openssl/binding.py in <module>
#      13 from cryptography.exceptions import InternalError
# ---> 14 from cryptography.hazmat.bindings._openssl import ffi, lib
#      15 from cryptography.hazmat.bindings.openssl._conditional import CONDITIONAL_NAMES
#
# ImportError: libffi.so.7: cannot open shared object file: No such file or directory
#
# During handling of the above exception, another exception occurred:
#
# Exception                                 Traceback (most recent call last)
# /tmp/ipykernel_20800/205036197.py in <module>
# ----> 1 gis = GIS()
#       2 print(f"Connected to {gis.properties.portalHostname} as {gis.users.me.username}")
#
# ~/anaconda3/envs/csce590/lib/python3.8/site-packages/arcgis/gis/__init__.py in __init__(self, url, username, password, key_file, cert_file, verify_cert, set_active, client_id, profile, **kwargs)
#     481                                                 gis=self, is_admin=False)
#     482             except:
# --> 483                 pass
#     484         self._tools = _Tools(self)
#     485         if set_active:
#
# ~/anaconda3/envs/csce590/lib/python3.8/site-packages/arcgis/gis/__init__.py in __init__(self, url, username, password, key_file, cert_file, verify_cert, set_active, client_id, profile, **kwargs)
#     426             try:
#     427                 if self._is_hosted_nb_home:
# --> 428                     import warnings
#     429                     warnings.warn("You are logged on as %s with an administrator role, proceed with caution." % \
#     430                                   self.users.me.username)
#
# ~/anaconda3/envs/csce590/lib/python3.8/site-packages/arcgis/gis/_impl/_portalpy.py in __init__(self, url, username, password, key_file, cert_file, expiration, referer, proxy_host, proxy_port, connection, workdir, tokenurl, verify_cert, client_id, custom_auth, token, **kwargs)
#     203                          + 'pre-2.0 portals')
#     204             return
# --> 205
#     206         #user_names = _unpack(user_names, 'username')
#     207
#
# ~/anaconda3/envs/csce590/lib/python3.8/site-packages/arcgis/gis/_impl/_portalpy.py in get_properties(self, force)
#    1225             url               string, the URL for the resource represented by the item. Applies only to items that represent web-accessible resources such as map services.
#    1226             ----------------  --------------------------------------------------------
# -> 1227             type              string, the GIS content type of this item. Example types include Web Map, Map Service, Shapefile, and Web Mapping Application.
#    1228             ----------------  --------------------------------------------------------
#    1229             typeKeywords      string, a set of keywords that further describes the type of this item. Each item is tagged with a set of type keywords that are derived based on its primary type.
#
# ~/anaconda3/envs/csce590/lib/python3.8/site-packages/arcgis/gis/_impl/_portalpy.py in get_properties(self, force)
#    1205
#    1206         :return:
# -> 1207             None if the item is not found and returns a dictionary object if the item is found
#    1208             the dictionary has the following keys:
#    1209
#
# ~/anaconda3/envs/csce590/lib/python3.8/site-packages/arcgis/gis/_impl/_con/_connection.py in post(self, path, params, files, **kwargs)
#    1066         if self._auth.lower() == 'pro' and \
#    1067            HASARCPY:
# -> 1068             resp = arcpy.GetSigninToken()
#    1069             if resp:
#    1070                 if 'referer' in resp:
#
# Exception: A general error occurred: libffi.so.7: cannot open shared object file: No such file or directory
